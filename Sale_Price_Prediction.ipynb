# %%
#Importing all the libraries
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Loading Data

# %%
# Read the training and test datasets
data = pd.read_csv('train.csv')
train_data = data.drop(columns=['SalePrice'])
train_size = len(train_data)
test_data = pd.read_csv('test.csv')

# %% [markdown]
# # Data Preprocessing

# %%
# Combining the train and test data and doing imputation and encoding of categorical features on combined data
combined_data = pd.concat([train_data, test_data], ignore_index=True)

# Define the imputer(Here most_frequent will take mode instead of mean in numerical feature because it handles outliers )
imputer = SimpleImputer(strategy='most_frequent')

# Impute missing values for training data
train_imputed = pd.DataFrame(imputer.fit_transform(combined_data), columns=combined_data.columns)

# %%
df = pd.DataFrame(train_imputed)

# Perform encoding on categorical features 
encoded_df_train = pd.get_dummies(df, columns=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
    'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
    'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
    'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
    'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
    'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
    'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
    'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
    'SaleType', 'SaleCondition'])

# %%
train_imputed = encoded_df_train.iloc[:train_size]
test_imputed = encoded_df_train.iloc[train_size:]

# %% [markdown]
# # Exploratory Data Analysis

# %%
# creating correlation matrix for checking multicollinearity
correlation_matrix = train_imputed.corr()
correlation_matrix
# Out:
#                              Id  MSSubClass  LotFrontage   LotArea  \
# Id                     1.000000    0.011156    -0.012497 -0.033226
# MSSubClass             0.011156    1.000000    -0.349116 -0.139781
# LotFrontage           -0.012497   -0.349116     1.000000  0.281283
# LotArea               -0.033226   -0.139781     0.281283  1.000000
# OverallQual           -0.028365    0.032628     0.236891  0.105806
# ...                         ...         ...          ...       ...
# SaleCondition_AdjLand -0.034852    0.016241    -0.032288 -0.013208
# SaleCondition_Alloca  -0.009018    0.030002    -0.017382  0.008966
# SaleCondition_Family   0.004865    0.000983     0.019685 -0.010781
# SaleCondition_Normal   0.015881    0.024359    -0.090650  0.005711
# SaleCondition_Partial -0.020738   -0.051068     0.146296  0.022635
#
#                        OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id                       -0.028365     0.012609  -0.012713     -0.021998
# MSSubClass                0.032628    -0.059316   0.027850      0.040581
# LotFrontage               0.236891    -0.056461   0.107427      0.087325
# LotArea                   0.105806    -0.005636   0.014228      0.013788
# OverallQual               1.000000    -0.091932   0.572323      0.550684
# ...                            ...          ...        ...           ...
# SaleCondition_AdjLand    -0.041677    -0.038888  -0.045601     -0.040294
# SaleCondition_Alloca     -0.044950    -0.033444  -0.010104     -0.020727
# SaleCondition_Family     -0.025515    -0.023873  -0.035785     -0.048056
# SaleCondition_Normal     -0.143282     0.161642  -0.158427     -0.120577
# SaleCondition_Partial     0.323295    -0.151659   0.343895      0.322837
#
#                        MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# Id                      -0.051071   -0.005024  ...       -0.020738
# MSSubClass               0.023573   -0.069836  ...        0.014005
# LotFrontage              0.174146    0.199171  ...       -0.046341
# LotArea                  0.103321    0.214103  ...       -0.015040
# OverallQual              0.407252    0.239666  ...       -0.021172
# ...                           ...         ...  ...             ...
# SaleCondition_AdjLand   -0.011783   -0.014874  ...       -0.003073
# SaleCondition_Alloca    -0.013748    0.021369  ...       -0.005337
# SaleCondition_Family    -0.009535    0.000765  ...       -0.006909
# SaleCondition_Normal    -0.081539   -0.019560  ...        0.027414
# SaleCondition_Partial    0.162205    0.044912  ...       -0.017938
#
#                        SaleType_New  SaleType_Oth  SaleType_WD  \
# Id                        -0.018998      0.038920     0.026133
# MSSubClass                -0.045156     -0.014555     0.026359
# LotFrontage                0.147674     -0.019493    -0.106995
# LotArea                    0.020039     -0.005722    -0.002292
# OverallQual                0.327412     -0.057962    -0.225013
# ...                             ...           ...          ...
# SaleCondition_AdjLand     -0.015827     -0.002378     0.020457
# SaleCondition_Alloca      -0.027489     -0.004131     0.035530
# SaleCondition_Family      -0.035587     -0.005348     0.028599
# SaleCondition_Normal      -0.645698     -0.097031     0.634322
# SaleCondition_Partial      0.986819     -0.013885    -0.769559
#
#                        SaleCondition_Abnorml  SaleCondition_AdjLand  \
# Id                                  0.007009              -0.034852
# MSSubClass                          0.005003               0.016241
# LotFrontage                        -0.020409              -0.032288
# LotArea                            -0.029126              -0.013208
# OverallQual                        -0.103535              -0.041677
# ...                                      ...                    ...
# SaleCondition_AdjLand              -0.014289               1.000000
# SaleCondition_Alloca               -0.024817              -0.004772
# SaleCondition_Family               -0.032128              -0.006177
# SaleCondition_Normal               -0.582947              -0.112080
# SaleCondition_Partial              -0.083419              -0.016038
#
#                        SaleCondition_Alloca  SaleCondition_Family  \
# Id                                -0.009018              0.004865
# MSSubClass                         0.030002              0.000983
# LotFrontage                       -0.017382              0.019685
# LotArea                            0.008966             -0.010781
# OverallQual                       -0.044950             -0.025515
# ...                                     ...                   ...
# SaleCondition_AdjLand             -0.004772             -0.006177
# SaleCondition_Alloca               1.000000             -0.010729
# SaleCondition_Family              -0.010729              1.000000
# SaleCondition_Normal              -0.194663             -0.252006
# SaleCondition_Partial             -0.027856             -0.036062
#
#                        SaleCondition_Normal  SaleCondition_Partial
# Id                                 0.015881              -0.020738
# MSSubClass                         0.024359              -0.051068
# LotFrontage                       -0.090650               0.146296
# LotArea                            0.005711               0.022635
# OverallQual                       -0.143282               0.323295
# ...                                     ...                    ...
# SaleCondition_AdjLand             -0.112080              -0.016038
# SaleCondition_Alloca              -0.194663              -0.027856
# SaleCondition_Family              -0.252006              -0.036062
# SaleCondition_Normal               1.000000              -0.654323
# SaleCondition_Partial             -0.654323               1.000000
#
# [288 rows x 288 columns]

# %% [markdown]
# # Model Training

# %%
# Using GridSearch to find best parameter for DecisionTreeRegressor
X_train = train_imputed
y_train = data['SalePrice']

# Create a DecisionTreeRegressor model
model = DecisionTreeRegressor()

# Define the parameter grid to search
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Perform grid search with cross-validation
cv = KFold(n_splits=5, shuffle=True, random_state=42)  
grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 5}

# %%
# Create a DecisionTreeRegressor model with best parameters
model = DecisionTreeRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=5)

# Train the model on the training data
model.fit(X_train, y_train)

# Predicting the prices for test_imputed in y_pred_test
X_test = test_imputed
y_pred_test = model.predict(X_test)

# %%
predicted_prices = pd.Series(y_pred_test, name='Predicted_Prices')

# Combine test_data with predicted_prices
predicted_price_test_data = pd.concat([test_data, predicted_prices], axis=1)

# %% [markdown]
# # Test Data with predicted prices in Predicted_Prices column

# %%
predicted_price_test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            HLS    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  Predicted_Prices
# 0         6   2010        WD         Normal     119154.315625
# 1         6   2010        WD         Normal     138382.260000
# 2         3   2010        WD         Normal     181321.257009
# 3         6   2010        WD         Normal     181321.257009
# 4         1   2010        WD         Normal     211136.605263
# ...     ...    ...       ...            ...               ...
# 1454      6   2006        WD         Normal     119154.315625
# 1455      4   2006        WD        Abnorml     119154.315625
# 1456      9   2006        WD        Abnorml     138382.260000
# 1457      7   2006        WD         Normal     119154.315625
# 1458     11   2006        WD         Normal     211563.636364
#
# [1459 rows x 81 columns]

# %% [markdown]
# # Exporting Output in excel

# %%
predicted_price_test_data.to_csv('predicted_price_test_data.csv')
